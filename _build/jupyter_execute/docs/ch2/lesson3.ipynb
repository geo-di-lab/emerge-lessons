# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/geo-di-lab/emerge-lessons/blob/main/docs/ch2/lesson3.ipynb)

# %% [markdown]
# # Map GLOBE Citizen Science Data
# Visualize the GLOBE Mosquito Habitat Mapper and Land Cover data on maps.

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap

mosquito = gpd.read_file('https://github.com/geo-di-lab/emerge-lessons/raw/refs/heads/main/docs/data/globe_mosquito.zip')
land_cover = gpd.read_file('https://github.com/geo-di-lab/emerge-lessons/raw/refs/heads/main/docs/data/globe_land_cover.zip')

# %%
# Filter to those within Florida
fl = gpd.read_file('https://github.com/geo-di-lab/emerge-lessons/raw/refs/heads/main/docs/data/florida_boundary.geojson')[['geometry']]

mosquito = gpd.sjoin(mosquito, fl, how="inner", predicate='intersects') \
          .drop(columns=['index_right']) \
          .reset_index(drop=True)

land_cover = gpd.sjoin(land_cover, fl, how="inner", predicate='intersects') \
          .drop(columns=['index_right']) \
          .reset_index(drop=True)

# %% [markdown]
# Map mosquito data in Florida from 2018 to 2024.

# %%
# List of columns we have access to
mosquito.columns
# Out:
# Index(['CountryCode', 'CountryName', 'Elevation', 'AbdomenCloseupPhotoUrls',
#        'BreedingGroundEliminated', 'Comments', 'DataSource', 'ExtraData',
#        'Genus', 'GlobeTeams', 'LarvaFullBodyPhotoUrls', 'LarvaeCount',
#        'LastIdentifyStage', 'LocationAccuracyM', 'LocationMethod',
#        'MeasuredAt', 'MeasurementElevation', 'MeasurementLatitude',
#        'MeasurementLongitude', 'MosquitoAdults', 'MosquitoEggs',
#        'MosquitoHabitatMapperId', 'MosquitoPupae', 'Species', 'Userid',
#        'WaterSource', 'WaterSourcePhotoUrls', 'WaterSourceType',
#        'OrganizationId', 'OrganizationName', 'Protocol', 'SiteId', 'SiteName',
#        'MeasuredDate', 'LarvaeCountProcessed', 'geometry'],
#       dtype='object')

# %%
# Create empty map zoomed to Florida
map = folium.Map(location=[28.263363, -83.497652], tiles="Cartodb dark_matter", zoom_start=7)

# Add each point as a marker on the map
for idx, row in mosquito.iterrows():
    popup_content = f"<b>Date:</b> {row['MeasuredDate']}<br><b>Water Source:</b> {row['WaterSourceType']}<br><b>Longitude:</b> {row['MeasurementLongitude']}<br><b>Latitude:</b> {row['MeasurementLatitude']}"
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=folium.Popup(popup_content, max_width=300)
    ).add_to(map)

display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a789767e386afcadfdb6f168607caf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a789767e386afcadfdb6f168607caf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a789767e386afcadfdb6f168607caf0 = L.map(
#                 &quot;map_9a789767e386afcadfdb6f168607caf0&quot;,
#                 {
#                     center: [28.263363, -83.497652],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0b9f6ffc48570ae69d18a6416bd2f7a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0b9f6ffc48570ae69d18a6416bd2f7a.addTo(map_9a789767e386afcadfdb6f168607caf0);
#
#
#             var marker_76b4e016efbfbb7930c2fa96b94e719a = L.marker(
#                 [28.104842, -82.479132],
#                 {
# }
#             ).addTo(map_9a789767e386afcadfdb6f168607caf0);
#
#
#         var popup_057574d73d39bdd4aca0c5664513099e = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_cd00e0e533830044358fbb6bcb00254d = $(`&lt;div id=&quot;html_cd00e0e533830044358fbb6bcb00254d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-06&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; still: lake/pond/swamp&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.479&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 28.1054&lt;/div&gt;`)[0];
#                 popup_057574d73d39bdd4aca0c5664513099e.setContent(html_cd00e0e533830044358fbb6bcb00254d);
#
#
#
#         marker_76b4e016efbfbb7930c2fa96b94e719a.bindPopup(popup_057574d73d39bdd4aca0c5664513099e)
#         ;
#
#
#
#
#             var marker_bfbb16102b373d1573be33d69c3e282d = L.marker(
#                 [28.10394, -82.479119],
#                 {
# }
#             ).addTo(map_9a789767e386afcadfdb6f168607caf0);
#
#
#         var popup_379d848417eb53a546d8ebf29539eb82 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_307b4a806713361739bc12d2dd20767e = $(`&lt;div id=&quot;html_307b4a806713361739bc12d2dd20767e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-06&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; flowing: still water found next to river or stream&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.4784&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 28.1042&lt;/div&gt;`)[0];
#                 popup_379d848417eb53a546d8ebf29539eb82.setContent(html_307b4a806713361739bc12d2dd20767e);
#
#
#
#         marker_bfbb16102b373d1573be33d69c3e282d.bindPopup(popup_379d848417eb53a546d8ebf29539eb82)
#         ;
#
#
#
#
#             var marker_d952acca405c6b05a39f3384ec4d164e = L.marker(
#                 [28.103918, -82.481155],
#                 {
# }
#             ).addTo(map_9a789767e386afcadfdb6f168607caf0);
#
#
#         var popup_1e827dbfe8647564c42cc65672ff566a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_1e8f77225ebef32b5af764680a3851ef = $(`&lt;div id=&quot;html_1e8f77225ebef32b5af764680a3851ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-06&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; still: lake/pond/swamp&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.4807&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 28.1045&lt;/div&gt;`)[0];
#                 popup_1e827dbfe8647564c42cc65672ff566a.setContent(html_1e8f77225ebef32b5af764680a3851ef);
#
#
#
#         marker_d952acca405c6b05a39f3384ec4d164e.bindPopup(popup_1e827dbfe8647564c42cc65672ff566a)
#         ;
#
#
#
#
#             var marker_5f221291d5921b24d7a3373df3d12638 = L.marker(
#                 [27.714311, -82.690862],
#                 {
# }
#             ).addTo(map_9a789767e386afcadfdb6f168607caf0);
#
#
#         var popup_5c21bd17dc815527e1d8e0b3bd8cbbbf = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f4066860dab1571dc9ead6a461bb5c0b = $(`&lt;div id=&quot;html_f4066860dab1571dc9ead6a461bb5c0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-16&lt;br&gt;&lt;b&gt;Water Source:&lt;/b&gt; still: lake/pond/swamp&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -82.69&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.7144&lt;/div&gt;`)[0];
#                 popup_5c21bd17dc815527e1d8e0b3bd8cbbbf.setContent(html_f4066860dab1571dc9ead6a461bb5c0b);

# %% [markdown]
# In the map, click on one of the points to see a pop-up that includes the date, water source type, longitude and latitude of the observation (which was submitted via the GLOBE Observer app).

# %% [markdown]
# Map land cover data from 2018 to 2024.

# %%
# List of columns we have access to
land_cover.columns
# Out:
# Index(['CountryCode', 'CountryName', 'Elevation', 'DataSource',
#        'DownwardCaption', 'DownwardExtraData', 'DownwardPhotoUrl', 'DryGround',
#        'EastCaption', 'EastClassifications', 'EastExtraData', 'EastPhotoUrl',
#        'Feature1Caption', 'Feature1ExtraData', 'Feature1PhotoUrl',
#        'Feature2Caption', 'Feature2ExtraData', 'Feature2PhotoUrl',
#        'Feature3Caption', 'Feature3ExtraData', 'Feature3PhotoUrl',
#        'Feature4Caption', 'Feature4ExtraData', 'Feature4PhotoUrl',
#        'FieldNotes', 'GlobeTeams', 'LandCoverId', 'LeavesOnTrees',
#        'LocationAccuracyM', 'LocationMethod', 'MeasuredAt',
#        'MeasurementElevation', 'MeasurementLatitude', 'MeasurementLongitude',
#        'MucCode', 'MucDescription', 'MucDetails', 'Muddy', 'NorthCaption',
#        'NorthClassifications', 'NorthExtraData', 'NorthPhotoUrl',
#        'RainingSnowing', 'SnowIce', 'SouthCaption', 'SouthClassifications',
#        'SouthExtraData', 'SouthPhotoUrl', 'StandingWater', 'UpwardCaption',
#        'UpwardExtraData', 'UpwardPhotoUrl', 'Userid', 'WestCaption',
#        'WestClassifications', 'WestExtraData', 'WestPhotoUrl',
#        'OrganizationId', 'OrganizationName', 'Protocol', 'SiteId', 'SiteName',
#        'MeasuredDate', 'geometry'],
#       dtype='object')

# %%
# Create empty map zoomed to Florida
map = folium.Map(location=[28.263363, -83.497652], tiles="Cartodb dark_matter", zoom_start=7)

# Add each point as a marker on the map
for idx, row in land_cover.iterrows():
    popup_content = f"<b>Date:</b> {row['MeasuredDate']}<br><b>MUC:</b> {row['MucDescription']}<br><b>Longitude:</b> {row['MeasurementLongitude']}<br><b>Latitude:</b> {row['MeasurementLatitude']}"
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=folium.Popup(popup_content, max_width=300)
    ).add_to(map)

display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fbe093cbe58599cb41a2cb5402bb19a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fbe093cbe58599cb41a2cb5402bb19a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fbe093cbe58599cb41a2cb5402bb19a = L.map(
#                 &quot;map_3fbe093cbe58599cb41a2cb5402bb19a&quot;,
#                 {
#                     center: [28.263363, -83.497652],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82d788e1badeac54b97b7e05b3d97574 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82d788e1badeac54b97b7e05b3d97574.addTo(map_3fbe093cbe58599cb41a2cb5402bb19a);
#
#
#             var marker_bb1696425299f6bc181024dd0c48e97e = L.marker(
#                 [30.374141, -86.223606],
#                 {
# }
#             ).addTo(map_3fbe093cbe58599cb41a2cb5402bb19a);
#
#
#         var popup_994232b78b242726cb77754445de014c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f982d3402524f3d36211962e34c385c4 = $(`&lt;div id=&quot;html_f982d3402524f3d36211962e34c385c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-10-12&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; Urban, Commercial Property&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -86.2233&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 30.3748&lt;/div&gt;`)[0];
#                 popup_994232b78b242726cb77754445de014c.setContent(html_f982d3402524f3d36211962e34c385c4);
#
#
#
#         marker_bb1696425299f6bc181024dd0c48e97e.bindPopup(popup_994232b78b242726cb77754445de014c)
#         ;
#
#
#
#
#             var marker_c88b70cc8345a4c56cb4f7f97de615a2 = L.marker(
#                 [27.967085, -81.924205],
#                 {
# }
#             ).addTo(map_3fbe093cbe58599cb41a2cb5402bb19a);
#
#
#         var popup_180500ef0ea36f2019c580a23445f279 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_419c8c58aa83b23f38ec1a1c60fa89b9 = $(`&lt;div id=&quot;html_419c8c58aa83b23f38ec1a1c60fa89b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-05&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -81.9234&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.9671&lt;/div&gt;`)[0];
#                 popup_180500ef0ea36f2019c580a23445f279.setContent(html_419c8c58aa83b23f38ec1a1c60fa89b9);
#
#
#
#         marker_c88b70cc8345a4c56cb4f7f97de615a2.bindPopup(popup_180500ef0ea36f2019c580a23445f279)
#         ;
#
#
#
#
#             var marker_42d2bbc801e5f8f09fc5ed070abad004 = L.marker(
#                 [27.966182, -81.924197],
#                 {
# }
#             ).addTo(map_3fbe093cbe58599cb41a2cb5402bb19a);
#
#
#         var popup_8d70be4a6ccc67aa79e4b4eb85c8076a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_5243651e0b363ac70f4b644c4e1ebcc9 = $(`&lt;div id=&quot;html_5243651e0b363ac70f4b644c4e1ebcc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-05&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -81.9234&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.967&lt;/div&gt;`)[0];
#                 popup_8d70be4a6ccc67aa79e4b4eb85c8076a.setContent(html_5243651e0b363ac70f4b644c4e1ebcc9);
#
#
#
#         marker_42d2bbc801e5f8f09fc5ed070abad004.bindPopup(popup_8d70be4a6ccc67aa79e4b4eb85c8076a)
#         ;
#
#
#
#
#             var marker_a72eab75ca28c1fff2b35d647291b26d = L.marker(
#                 [27.967085, -81.924205],
#                 {
# }
#             ).addTo(map_3fbe093cbe58599cb41a2cb5402bb19a);
#
#
#         var popup_81b97ed7347ad55d0af2daaa3ca0291d = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_9641ace4c4c2d8013d298768adc4cb50 = $(`&lt;div id=&quot;html_9641ace4c4c2d8013d298768adc4cb50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Date:&lt;/b&gt; 2024-09-05&lt;br&gt;&lt;b&gt;MUC:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;Longitude:&lt;/b&gt; -81.9234&lt;br&gt;&lt;b&gt;Latitude:&lt;/b&gt; 27.9671&lt;/div&gt;`)[0];
#                 popup_81b97ed7347ad55d0af2daaa3ca0291d.setContent(html_9641ace4c4c2d8013d298768adc4cb50);
#
#
#
#         marker_a72eab75ca28c1fff2b35d647291b26d.bindPopup(popup_81b97ed7347ad55d0af2daaa3ca0291d)
#         ;

# %% [markdown]
# We created some simple interactive maps of the GLOBE data. In the next session, we'll make heatmaps showing the global distribution of these points.
